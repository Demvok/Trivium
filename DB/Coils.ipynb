# %%
import pandas as pd
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 200)

# %%
df = pd.read_csv('./raw_csv/coils-data.csv', sep=';', skip_blank_lines=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2423 entries, 0 to 2422
# Data columns (total 44 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    2423 non-null   int64
#  1   time                  2423 non-null   object
#  2   user-stock            2423 non-null   object
#  3   madein                2423 non-null   object
#  4   weight                2423 non-null   int64
#  5   format                2423 non-null   object
#  6   1C                    2422 non-null   object
#  7   status                2423 non-null   object
#  8   time_ change          2276 non-null   object
#  9   samcod                2276 non-null   object
#  10  number-coil           2423 non-null   object
#  11  length0               2422 non-null   float64
#  12  date-of-man           2423 non-null   object
#  13  num_truck_in          1864 non-null   object
#  14  num_trailer_in        1864 non-null   object
# ...

# %%
df.rename({'id': 'coil_id', 'samcod': 'fk_order_id', 'number-coil': 'coil_name'}, axis=1, inplace=True)

# %%
for col in [elem for elem in df.columns if elem not in ['samcod',]]:
    print( f"{col} : {df[col].unique()}")
# Out:
# coil_id : [  63   64   65 ... 2555 2556 2557]
# time : ['13.02.2023 10:57' '13.02.2023 10:58' '13.02.2023 10:59' ...
#  '14.05.2024 9:29' '14.05.2024 9:30' '14.05.2024 9:31']
# user-stock : ['Prodan_A' 'prodanA' 'admin' 'Belivskyi_S' 'Ruda_L' 'Rusnak_D'
#  'Kozhevnykov_O' 'Hluhyi_V' 'Shubravskyi_R' 'Melnyk_А' 'Podkolzyna_K'
#  'Podkolzina_K' 'Litavskyi_V']
# madein : ['RAS' 'HBI' 'USK' 'ERD' 'BAO' 'HEN' 'DON']
# weight : [10623 10234  8991 ...  8490  9068  9903]
# format : ['0.14-975-TS550-S2828' '0.16-942-TS340-S2020' '0.14-913-TS480-S2020'
#  '0.18-860-TH550-F2028' '0.16-920-TS340-S2828' '0.19-895-TH550-F2820'
#  '0.17-959-TH550-F2828' '0.20-808-TH550-S2828' '0.17-922-TH580-S5628'
#  '0.17-954-TH435-S2828' '0.27-950-TH435-F5628' '0.18-808-TH550-S2828'
#  '0.18-860-TH550-F2820' '0.20-838-TH550-S2828' '0.17-860-TH550-F2828'
#  '0.17-922-TH550-F2828' '0.20-908-TS260-S2828' '0.27-950-TH435-S2828'
#  '0.18-877-TS275-S2828' '0.15-975-TS550-S2828' '0.16-942-TS480-S2020'
# ...

# %%
df.to_json('./done_json/factCoil.json', orient='records')

# %%
df.loc[df['user-stock'] == '']
# Out:
# Empty DataFrame
# Columns: [coil_id, time, user-stock, madein, weight, format, 1C, status, time_ change, fk_order_id, coil_name, length0, date-of-man, num_truck_in, num_trailer_in, driver_in, trailer_clean, condition_tent, trailer_smell, trailer_straps, pests, coments_in, operator-littell, non-availability_mat, non-availability_doc, heat_treatment, physical_damage, hygienic_condition, order_label, differential_marking, step_cutting, width_cutting, coments_litt_cut, sp-user, sp-time, sp-visual, sp-pinhole, sp-thickness, sp-quality, total-spoilage, total_quality_sheets, total_sheets_coil, length_cutting, sp-coments]
# Index: []
